# %%
from neuromesh.mesh import MeshManager

mm_cell = MeshManager()
mm_cell.load_mesh("../data/cell_clean.obj")
mm_ts = MeshManager()
mm_ts.load_mesh("../data/TS1_alone.obj")
mm_result = mm_cell.subtract_mesh(mm_ts)
mm_result.visualize_mesh_3d()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\GitHub\neuromesh\neuromesh\mesh.py:1269, in MeshManager.subtract_mesh(self, other, repair_before, repair_after, engine, validate)
#    1267     logger.info("Performing boolean difference with engine: %s", engine)
# -> 1269 result_mesh = self.mesh.difference(other_mesh, engine=engine)
#    1271 # Check if result is valid
#
# File c:\Users\MainUser\Documents\GitHub\neuromesh\.venv\Lib\site-packages\trimesh\base.py:3032, in Trimesh.difference(self, other, engine, check_volume, **kwargs)
#    3010 """
#    3011 Boolean difference between this mesh and other meshes.
#    3012
#    (...)   3030   Difference between self and other Trimesh objects
#    3031 """
# -> 3032 return boolean.difference(
#    3033     meshes=util.chain(self, other),
#    3034     engine=engine,
#    3035     check_volume=check_volume,
# ...
